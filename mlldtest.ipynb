# %%
# !git clone https://github.com/peanutshu11/Multi-Level-Logit-Distillation.git

# %cd Multi-Level-Logit-Distillation
# !pip install -e .
# !pip install tensorboardX
# !pip install yacs
# !pip install wandb
# Out:
# Cloning into 'Multi-Level-Logit-Distillation'...
# remote: Enumerating objects: 199, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 199 (delta 9), reused 13 (delta 5), pack-reused 172 (from 2)
# Receiving objects: 100% (199/199), 53.23 MiB | 44.49 MiB/s, done.
# Resolving deltas: 100% (93/93), done.
# /kaggle/working/Multi-Level-Logit-Distillation
# Obtaining file:///kaggle/working/Multi-Level-Logit-Distillation
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for mdistiller
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !wget https://github.com/megvii-research/mdistiller/releases/download/checkpoints/cifar_teachers.tar
# Out:
# --2025-12-02 15:44:32--  https://github.com/megvii-research/mdistiller/releases/download/checkpoints/cifar_teachers.tar
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !mkdir ./download_ckpts
# !tar -xvf  ./cifar_teachers.tar -C ./download_ckpts
# Out:
# cifar_teachers/
# cifar_teachers/resnet110_vanilla/
# cifar_teachers/resnet110_vanilla/ckpt_epoch_240.pth
# cifar_teachers/ResNet50_vanilla/
# cifar_teachers/ResNet50_vanilla/ckpt_epoch_240.pth
# cifar_teachers/resnet32x4_vanilla/
# cifar_teachers/resnet32x4_vanilla/ckpt_epoch_240.pth
# cifar_teachers/resnet56_vanilla/
# cifar_teachers/resnet56_vanilla/ckpt_epoch_240.pth
# cifar_teachers/vgg13_vanilla/
# cifar_teachers/vgg13_vanilla/ckpt_epoch_240.pth
# cifar_teachers/wrn_40_2_vanilla/
# cifar_teachers/wrn_40_2_vanilla/ckpt_epoch_240.pth

# %%
# !python3 setup.py develop
# Out:
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
# ...

# %%
# !python3 tools/train_ours.py --cfg configs/cifar100/ours/res32x4_res8x4_zscore.yaml
# Out:
# [INFO] CONFIG:
# DATASET:
#   NUM_WORKERS: 2
#   TEST:
#     BATCH_SIZE: 64
#   TYPE: cifar100
# DISTILLER:
#   STUDENT: resnet8x4
#   TEACHER: resnet32x4
#   TYPE: KD_z_scores
# EXPERIMENT:
#   NAME: ''
#   PROJECT: cifar100_baselines
#   TAG: KD_z_scores,res32x4,res8x4
# LOG:
#   PREFIX: ./output
#   SAVE_CHECKPOINT_FREQ: 40
#   TENSORBOARD_FREQ: 500
#   WANDB: false
# SOLVER:
#   BATCH_SIZE: 64
#   EPOCHS: 240
#   LR: 0.025
#   LR_DECAY_RATE: 0.1
#   LR_DECAY_STAGES:
#   - 150
#   - 180
#   - 210
#   MOMENTUM: 0.9
#   TRAINER: ours
#   TYPE: SGD
#   WEIGHT_DECAY: 0.0005
#
# 100%|████████████████████████████████████████| 169M/169M [00:14<00:00, 11.4MB/s]
# [INFO] Loading teacher model
# [INFO] Extra parameters of KD_z_scores: 0
# [TRAIN] Epoch:1| Time(data):0.000| Time(train):0.059| Loss:7.1521| Top-1:13.666|
# [EVAL] Top-1:18.170| Top-5:46.830: 100%|██████| 157/157 [00:02<00:00, 57.23it/s]
# [TRAIN] Epoch:2| Time(data):0.000| Time(train):0.056| Loss:5.7137| Top-1:28.516|
# ...
